# %%
import pandas as pd
import numpy as np
file_path = 'data/online_retail.csv'
sales_data = pd.read_csv(file_path)
sales_data['InvoiceDate'] = pd.to_datetime(sales_data['InvoiceDate'])
sales_data.dropna(inplace=True, subset=['CustomerID', 'InvoiceDate'])
sales_data.info()
sales_data['TotalPrice'] = sales_data['Quantity'] * sales_data['UnitPrice']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
sales_data.set_index('InvoiceDate', inplace=True)
sales_data.head(10)
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 2010-12-01 08:26:00    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 2010-12-01 08:26:00    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 2010-12-01 08:28:00    536366     22633               HAND WARMER UNION JACK
# 2010-12-01 08:28:00    536366     22632            HAND WARMER RED POLKA DOT
# 2010-12-01 08:34:00    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
#
#                      Quantity  UnitPrice  CustomerID         Country  \
# InvoiceDate
# ...

# %%
sales_data['year']=sales_data.index.year
sales_data['year'].head
# Out:
# <bound method NDFrame.head of InvoiceDate
# 2010-12-01 08:26:00    2010
# 2010-12-01 08:26:00    2010
# 2010-12-01 08:26:00    2010
# 2010-12-01 08:26:00    2010
# 2010-12-01 08:26:00    2010
#                        ...
# 2011-12-09 12:50:00    2011
# 2011-12-09 12:50:00    2011
# 2011-12-09 12:50:00    2011
# 2011-12-09 12:50:00    2011
# 2011-12-09 12:50:00    2011
# Name: year, Length: 406829, dtype: int32>

# %%
sales_data['month']=sales_data.index.month
sales_data['month'].head(10)
# Out:
# InvoiceDate
# 2010-12-01 08:26:00    12
# 2010-12-01 08:26:00    12
# 2010-12-01 08:26:00    12
# 2010-12-01 08:26:00    12
# 2010-12-01 08:26:00    12
# 2010-12-01 08:26:00    12
# 2010-12-01 08:26:00    12
# 2010-12-01 08:28:00    12
# 2010-12-01 08:28:00    12
# 2010-12-01 08:34:00    12
# Name: month, dtype: int32

# %%
sales_data['weekday']=sales_data.index.weekday
sales_data['weekday'].head(10)
# Out:
# InvoiceDate
# 2010-12-01 08:26:00    2
# 2010-12-01 08:26:00    2
# 2010-12-01 08:26:00    2
# 2010-12-01 08:26:00    2
# 2010-12-01 08:26:00    2
# 2010-12-01 08:26:00    2
# 2010-12-01 08:26:00    2
# 2010-12-01 08:28:00    2
# 2010-12-01 08:28:00    2
# 2010-12-01 08:34:00    2
# Name: weekday, dtype: int32

# %%
sales_data['day']=sales_data.index.day
sales_data['day'].head(15)
# Out:
# InvoiceDate
# 2010-12-01 08:26:00    1
# 2010-12-01 08:26:00    1
# 2010-12-01 08:26:00    1
# 2010-12-01 08:26:00    1
# 2010-12-01 08:26:00    1
# 2010-12-01 08:26:00    1
# 2010-12-01 08:26:00    1
# 2010-12-01 08:28:00    1
# 2010-12-01 08:28:00    1
# 2010-12-01 08:34:00    1
# 2010-12-01 08:34:00    1
# 2010-12-01 08:34:00    1
# 2010-12-01 08:34:00    1
# 2010-12-01 08:34:00    1
# 2010-12-01 08:34:00    1
# Name: day, dtype: int32

# %%
sales_data['minute']=sales_data.index.minute
sales_data['minute'].head(10)
# Out:
# InvoiceDate
# 2010-12-01 08:26:00    26
# 2010-12-01 08:26:00    26
# 2010-12-01 08:26:00    26
# 2010-12-01 08:26:00    26
# 2010-12-01 08:26:00    26
# 2010-12-01 08:26:00    26
# 2010-12-01 08:26:00    26
# 2010-12-01 08:28:00    28
# 2010-12-01 08:28:00    28
# 2010-12-01 08:34:00    34
# Name: minute, dtype: int32

# %%
sales_data
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...                       ...       ...                                  ...
# 2011-12-09 12:50:00    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 2011-12-09 12:50:00    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 2011-12-09 12:50:00    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 2011-12-09 12:50:00    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 2011-12-09 12:50:00    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
# ...

# %%
df_2011 = sales_data.loc['2011']
df_2011.head(10)
# Out:
#                     InvoiceNo StockCode                       Description  \
# InvoiceDate
# 2011-01-04 10:00:00    539993     22386           JUMBO BAG PINK POLKADOT
# 2011-01-04 10:00:00    539993     21499                BLUE POLKADOT WRAP
# 2011-01-04 10:00:00    539993     21498               RED RETROSPOT WRAP
# 2011-01-04 10:00:00    539993     22379          RECYCLING BAG RETROSPOT
# 2011-01-04 10:00:00    539993     20718         RED RETROSPOT SHOPPER BAG
# 2011-01-04 10:00:00    539993    85099B           JUMBO BAG RED RETROSPOT
# 2011-01-04 10:00:00    539993     20682  RED RETROSPOT CHILDRENS UMBRELLA
# 2011-01-04 10:00:00    539993     22961            JAM MAKING SET PRINTED
# 2011-01-04 10:00:00    539993     22667             RECIPE BOX RETROSPOT
# 2011-01-04 10:00:00    539993     22898     CHILDRENS APRON APPLES DESIGN
#
#                      Quantity  UnitPrice  CustomerID         Country  \
# InvoiceDate
# ...

# %%
df_2011_dec = sales_data.loc['2011-12']
df_2011_dec.head(10)
# Out:
#                     InvoiceNo StockCode                         Description  \
# InvoiceDate
# 2011-12-01 08:12:00   C579889     23245          SET OF 3 REGENCY CAKE TINS
# 2011-12-01 08:14:00   C579890     84947   ANTIQUE SILVER TEA GLASS ENGRAVED
# 2011-12-01 08:14:00   C579890     23374             RED SPOT PAPER GIFT BAG
# 2011-12-01 08:14:00   C579890     84945  MULTI COLOUR SILVER T-LIGHT HOLDER
# 2011-12-01 08:18:00   C579891     23485       BOTANICAL GARDENS WALL CLOCK
# 2011-12-01 08:18:00   C579891     23186      FRENCH STYLE STORAGE JAR CAFE
# 2011-12-01 08:23:00   C579892     23461               SWEETHEART BIRD HOUSE
# 2011-12-01 08:25:00   C579893     37449  CERAMIC CAKE STAND + HANGING CAKES
# 2011-12-01 08:26:00   C579894     23012     GLASS APOTHECARY BOTTLE PERFUME
# 2011-12-01 08:26:00   C579894     23568        EGG CUP HENRIETTA HEN CREAM
#
#                      Quantity  UnitPrice  CustomerID         Country  \
# InvoiceDate
# ...

# %%
df_2010_range = sales_data.loc['2010-12-01':'2010-12-10']
df_2010_range.head(10)
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 2010-12-01 08:26:00    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 2010-12-01 08:26:00    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 2010-12-01 08:28:00    536366     22633               HAND WARMER UNION JACK
# 2010-12-01 08:28:00    536366     22632            HAND WARMER RED POLKA DOT
# 2010-12-01 08:34:00    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
#
#                      Quantity  UnitPrice  CustomerID         Country  \
# InvoiceDate
# ...

# %%
date_range = pd.date_range(start='2024-01-01', end='2024-12-31', freq='D')
df_dates = pd.DataFrame(date_range, columns=['date'])
df_dates.head(10)
# Out:
#         date
# 0 2024-01-01
# 1 2024-01-02
# 2 2024-01-03
# 3 2024-01-04
# 4 2024-01-05
# 5 2024-01-06
# 6 2024-01-07
# 7 2024-01-08
# 8 2024-01-09
# 9 2024-01-10
